# %% [markdown]
# <a href="https://colab.research.google.com/github/alieha4/E-commerece/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/goibibo_flights_data.csv')

# %%
df.head()
# Out:
#   flight date   airline flight_num    class   from dep_time      to arr_time  \
# 0  26-06-2023  SpiceJet    SG-8709  economy  Delhi    18:55  Mumbai    21:05
# 1  26-06-2023  SpiceJet    SG-8157  economy  Delhi    06:20  Mumbai    08:40
# 2  26-06-2023   AirAsia     I5-764  economy  Delhi    04:25  Mumbai    06:35
# 3  26-06-2023   Vistara     UK-995  economy  Delhi    10:20  Mumbai    12:35
# 4  26-06-2023   Vistara     UK-963  economy  Delhi    08:50  Mumbai    11:10
#
#   duration  price     stops  Unnamed: 11  Unnamed: 12
# 0  02h 10m  6,013  non-stop          NaN          NaN
# 1  02h 20m  6,013  non-stop          NaN          NaN
# 2  02h 10m  6,016  non-stop          NaN          NaN
# 3  02h 15m  6,015  non-stop          NaN          NaN
# 4  02h 20m  6,015  non-stop          NaN          NaN

# %%
# Step 1: Install Necessary Libraries
# !pip install nltk gensim textblob sklearn

# Step 2: Load the Dataset
import pandas as pd

# Load the dataset
file_path = 'goibibo_flights_data.csv'  # Adjust the path as necessary if needed
data = pd.read_csv(file_path)

# Display the first few rows and dataset info
print(data.head())
print(data.info())  # Check column types and null values

# Step 3: Text Preprocessing
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize stop words and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    # Tokenize text
    tokens = word_tokenize(str(text).lower())
    # Remove stop words and punctuations, and lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word.isalpha() and word not in stop_words]
    return ' '.join(tokens)

# Assuming 'text_column' is the relevant text field in the dataset
data['cleaned_text'] = data['airline'].apply(preprocess_text)  # Adjust column name
print(data['cleaned_text'].head())

# Display column names
print(data.columns)
# Step 4: Word Embedding with Word2Vec
# from gensim.models import Word2Vec
# # Assuming `df` is your DataFrame with a `cleaned_text` column
# sentences = [row.split() for row in df['cleaned_text'].dropna()]
# from gensim.models import Word2Vec

# # Train a word2vec model on your cleaned_text data
# word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)


# # Prepare tokenized sentences for Word2Vec
# sentences = [sentence.split() for sentence in data['cleaned_text']]
# sentences = [[word] for word in data['airline'].tolist()]

# Train Word2Vec model
# word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
# word = "airline"
# if word in word2vec_model.wv:
#     print("Vector for 'airline':", word2vec_model.wv[word])
# else:
#     print(f"Word '{word}' not in vocabulary")


# # Example: Print word vector for a sample word
# print("Vector for 'duration':", word2vec_model.wv['duration'])  # Adjust word as relevant

# Step 5: Encoding Techniques

# Bag of Words
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_features=1000)
X_bow = vectorizer.fit_transform(data['cleaned_text']).toarray()
print("Bag of Words shape:", X_bow.shape)

# One-Hot Encoding
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
X_onehot = encoder.fit_transform(data[['cleaned_text']])  # Adjust column name if needed
print("One-Hot Encoding shape:", X_onehot.shape)

# Step 6: Parts of Speech (POS) Tagging
nltk.download('averaged_perceptron_tagger')
data['pos_tags'] = data['cleaned_text'].apply(lambda x: nltk.pos_tag(word_tokenize(x)))
print(data['pos_tags'].head())

# Q2: Perform Sentiment Analysis with TextBlob
from textblob import TextBlob

def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

data['sentiment'] = data['cleaned_text'].apply(get_sentiment)
print(data[['cleaned_text', 'sentiment']].head())

# Q2: Topic Modeling with LDA
from gensim import corpora
from gensim.models import LdaModel

# Prepare data for LDA
dictionary = corpora.Dictionary(sentences)
corpus = [dictionary.doc2bow(sentence) for sentence in sentences]

# Train LDA model
lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# Display topics
topics = lda_model.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#   flight date   airline flight_num    class   from dep_time      to arr_time  \
# 0  26-06-2023  SpiceJet    SG-8709  economy  Delhi    18:55  Mumbai    21:05
# 1  26-06-2023  SpiceJet    SG-8157  economy  Delhi    06:20  Mumbai    08:40
# 2  26-06-2023   AirAsia     I5-764  economy  Delhi    04:25  Mumbai    06:35
# 3  26-06-2023   Vistara     UK-995  economy  Delhi    10:20  Mumbai    12:35
# ...

# %%
# Install necessary libraries
# !pip install nltk gensim sklearn pandas textblob

# Step 2: Load the Dataset
import pandas as pd

# Load the dataset directly from the uploaded file path
file_path = '/content/goibibo_flights_data.csv'  # Adjust if needed
data = pd.read_csv(file_path)

# Display the first few rows and dataset info
print(data.head())
print(data.info())  # Check column types and null values

# Proceed with the rest of the code...

# %%
# Install necessary libraries
# !pip install nltk gensim scikit-learn pandas textblob

# %%
import pandas as pd
from gensim.models import Word2Vec

# Load your DataFrame (replace 'your_data_file.csv' with your actual data file)
df = pd.read_csv('/content/goibibo_flights_data.csv')

# Print columns to confirm
print(df.columns)

# If 'cleaned_text' is available, proceed to create sentences
if 'cleaned_text' in df.columns:
    sentences = [row.split() for row in df['cleaned_text'].dropna()]

    # Train the Word2Vec model
    word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

    # Example: Print word vector for a sample word
    word = "duration"
    if word in word2vec_model.wv:
        print("Vector for 'duration':", word2vec_model.wv[word])
    else:
        print(f"Word '{word}' not in vocabulary")
else:
    print("Column 'cleaned_text' does not exist in the DataFrame.")
# Out:
# Index(['flight date', 'airline', 'flight_num', 'class', 'from', 'dep_time',
#        'to', 'arr_time', 'duration', 'price', 'stops', 'Unnamed: 11',
#        'Unnamed: 12'],
#       dtype='object')
# Column 'cleaned_text' does not exist in the DataFrame.

# %%
-# Display column names
print(data.columns)
# Out:
# Index(['flight date', 'airline', 'flight_num', 'class', 'from', 'dep_time',
#        'to', 'arr_time', 'duration', 'price', 'stops', 'Unnamed: 11',
#        'Unnamed: 12'],
#       dtype='object')
